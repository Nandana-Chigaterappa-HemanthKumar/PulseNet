# %%
import pandas as pd
import numpy as np
import os
from glob import glob

# Function to extract features from Actigraphy data
def extract_features(data):
    required_columns = {'X', 'Y', 'Z', 'enmo', 'light'}
    if not required_columns.issubset(data.columns):
        raise ValueError(f"Missing required columns: {required_columns - set(data.columns)}")
    
    # Statistical features
    mean_x = data['X'].mean()
    mean_y = data['Y'].mean()
    mean_z = data['Z'].mean()
    std_x = data['X'].std()
    std_y = data['Y'].std()
    std_z = data['Z'].std()
    
    mean_enmo = data['enmo'].mean()
    std_enmo = data['enmo'].std()
    max_enmo = data['enmo'].max()
    min_enmo = data['enmo'].min()

    magnitude = np.sqrt(data['X']**2 + data['Y']**2 + data['Z']**2)
    mean_magnitude = magnitude.mean()
    std_magnitude = magnitude.std()

    activity_level = pd.cut(
        magnitude,
        bins=[0, 0.5, 1.0, 1.5, 2.0],
        labels=['Very Low', 'Low', 'Medium', 'High'],
        include_lowest=True
    ).mode()[0] if len(magnitude) > 0 else 'Unknown'

    inactivity_percentage = (data['enmo'] == 0).mean() * 100

    non_wear_percentage = (data['non_wear_flag'] == 1).mean() * 100 if 'non_wear_flag' in data.columns else None

    mean_light = data['light'].mean()
    max_light = data['light'].max()

    features = {
        'mean_x': mean_x,
        'mean_y': mean_y,
        'mean_z': mean_z,
        'std_x': std_x,
        'std_y': std_y,
        'std_z': std_z,
        'mean_enmo': mean_enmo,
        'std_enmo': std_enmo,
        'max_enmo': max_enmo,
        'min_enmo': min_enmo,
        'mean_magnitude': mean_magnitude,
        'std_magnitude': std_magnitude,
        'activity_level': activity_level,
        'inactivity_percentage': inactivity_percentage,
        'non_wear_percentage': non_wear_percentage,
        'mean_light': mean_light,
        'max_light': max_light
    }
    return pd.DataFrame([features])

# Directory containing participant files (replace with actual directory path)
participant_dir = "C:/Users/Lenovo/OneDrive/Desktop/SEM 2/ml/project/cleaned_series_train.parquet/"
output_file = "C:/Users/Lenovo/OneDrive/Desktop/SEM 2/ml/project/consolidated_features.parquet"

# Found all participant files
participant_files = glob(os.path.join(participant_dir, "*.parquet"))
print(f"Found {len(participant_files)} participant files.")

# Initialized an empty DataFrame to hold all features
all_features = pd.DataFrame()

# Processed each participant file
for participant_file in participant_files:
    try:
        participant_data = pd.read_parquet(participant_file)
        participant_features = extract_features(participant_data)
        
        # Added participant ID to the features
        participant_id = participant_file.split('id=')[-1].split('.')[0]
        participant_features['participant_id'] = participant_id
        
        # Appended to the consolidated DataFrame
        all_features = pd.concat([all_features, participant_features], ignore_index=True)
        print(f"Processed participant {participant_id}.")
    
    except Exception as e:
        print(f"Error processing file {participant_file}: {e}")

# Saved the consolidated DataFrame
try:
    all_features.to_parquet(output_file)
    print(f"Consolidated features saved successfully to {output_file}")
    print(all_features.shape)  # Debugging: Check the final DataFrame shape
except Exception as e:
    print(f"Error saving consolidated features: {e}")
# Out:
# Found 996 participant files.
# Processed participant 00115b9f.
# Processed participant 001f3379.
# Processed participant 00f332d1.
# Processed participant 01085eb3.
# Processed participant 012cadd8.
# Processed participant 012e3869.
# Processed participant 029a19c9.
# Processed participant 02cebf33.
# Processed participant 02cf7384.
# Processed participant 035c96dd.
# Processed participant 03a9019b.
# Processed participant 0417c91e.
# Processed participant 045a0a94.
# Processed participant 04afb6f9.
# Processed participant 04bb1a76.
# Processed participant 04cb2c30.
# Processed participant 04d06a9c.
# Processed participant 04f094a8.
# Processed participant 051680a0.
# Processed participant 055156e2.
# Processed participant 059eed01.
# Processed participant 05bbed1b.
# Processed participant 05db1b9b.
# Processed participant 05e94f88.
# Processed participant 063b16fc.
# Processed participant 064e8da5.
# Processed participant 0668373f.
# Processed participant 067b9287.
# Processed participant 06c8b2fb.
# Processed participant 06eb8adb.
# Processed participant 070386b2.
# Processed participant 07048067.
# Processed participant 0720320e.
# Processed participant 0745c390.
# Processed participant 080698b7.
# Processed participant 082df556.
# Processed participant 08577722.
# Processed participant 08660d12.
# Processed participant 089a6b19.
# Processed participant 09331bb8.
# Processed participant 0983654b.
# Processed participant 099e3614.
# Processed participant 09b29113.
# Processed participant 0a418b57.
# Processed participant 0a431608.
# Processed participant 0b4014f0.
# Processed participant 0b50f3fa.
# Processed participant 0b518637.
# Processed participant 0b7d7aec.
# Processed participant 0b7d9da6.
# Processed participant 0bd89878.
# Processed participant 0bfe4fc9.
# Processed participant 0c4e2d68.
# Processed participant 0c4eabac.
# Processed participant 0c98f822.
# Processed participant 0cbe4e54.
# Processed participant 0d01bbf2.
# Processed participant 0d279d77.
# Processed participant 0d4800c8.
# Processed participant 0d4fa8f4.
# Processed participant 0d570d3e.
# Processed participant 0d924604.
# Processed participant 0e3b0bd2.
# Processed participant 0ec403df.
# Processed participant 0ed2a3c8.
# Processed participant 0eddd8e5.
# Processed participant 0f6b71c4.
# Processed participant 0fbb3ca5.
# Processed participant 101774f0.
# Processed participant 101c27f1.
# Processed participant 108b8659.
# Processed participant 10ad8c48.
# Processed participant 10e46254.
# Processed participant 113f5798.
# Processed participant 11739de2.
# Processed participant 119d7562.
# Processed participant 119e181e.
# Processed participant 11be5d2e.
# Processed participant 11f9b26c.
# Processed participant 12380b06.
# Processed participant 12a607f6.
# Processed participant 1301f65d.
# Processed participant 1314bc8c.
# Processed participant 137baaec.
# Processed participant 13eee030.
# Processed participant 13fca10c.
# Processed participant 14391970.
# Processed participant 144a9a79.
# Processed participant 14568d61.
# Processed participant 1470a1df.
# Processed participant 14a6e58e.
# Processed participant 14b3d6e5.
# Processed participant 15227eef.
# Processed participant 154d1191.
# Processed participant 15dbc929.
# Processed participant 15f217a6.
# Processed participant 15f2e240.
# Processed participant 1606f203.
# Processed participant 1649ce22.
# Processed participant 17c1ae23.
# Processed participant 1837456f.
# Processed participant 18b8b2f6.
# Processed participant 19098ef0.
# Processed participant 1911731d.
# Processed participant 19455336.
# Processed participant 1957153d.
# Processed participant 1a803bfe.
# Processed participant 1aae1de3.
# Processed participant 1aff6762.
# Processed participant 1b2eea8f.
# Processed participant 1b32427b.
# Processed participant 1b329556.
# Processed participant 1b5b34bc.
# Processed participant 1b6fb363.
# Processed participant 1c063ebc.
# Processed participant 1c23295e.
# Processed participant 1c5ba087.
# Processed participant 1cd37b36.
# Processed participant 1d78b3c3.
# Processed participant 1e08b1dc.
# Processed participant 1e5f6199.
# Processed participant 1e87baed.
# Processed participant 1eda934b.
# Processed participant 1eea8df2.
# Processed participant 1eedf45e.
# Processed participant 1f2164a4.
# Processed participant 1f5835cd.
# Processed participant 1f65fa82.
# Processed participant 1f7bd44c.
# Processed participant 1fc07a80.
# Processed participant 1fed3943.
# Processed participant 214f46e8.
# Processed participant 215ca39b.
# Processed participant 218faf6f.
# Processed participant 21a76448.
# Processed participant 21eb6d47.
# Processed participant 221e37e0.
# Processed participant 22375702.
# Processed participant 224fc39a.
# Processed participant 22536a61.
# Processed participant 22b4191a.
# Processed participant 22c72c4e.
# Processed participant 22e44415.
# Processed participant 22f43a12.
# Processed participant 233b9425.
# Processed participant 23567787.
# Processed participant 23dafdab.
# Processed participant 23e024bd.
# Processed participant 23e71e7c.
# Processed participant 24398aed.
# Processed participant 2496c491.
# Processed participant 24a3b16d.
# Processed participant 24ab10c6.
# Processed participant 25849c6c.
# Processed participant 25a3a723.
# Processed participant 25eba023.
# Processed participant 260f542b.
# Processed participant 26190ddd.
# Processed participant 26aeacdf.
# Processed participant 26d541c2.
# Processed participant 2760be91.
# Processed participant 278e8a51.
# Processed participant 27d7e5e4.
# Processed participant 2812951b.
# Processed participant 2840643b.
# Processed participant 2898269f.
# Processed participant 28e973b1.
# Processed participant 29587a31.
# Processed participant 29b37b4a.
# Processed participant 29c54890.
# Processed participant 2a0b8386.
# Processed participant 2a3fcf9a.
# Processed participant 2a6a6b92.
# Processed participant 2a88cbe9.
# Processed participant 2a922ca4.
# Processed participant 2a9e0dee.
# Processed participant 2ac0bd9f.
# Processed participant 2afea280.
# Processed participant 2b34dcf3.
# Processed participant 2bac0893.
# Processed participant 2bbcfd43.
# Processed participant 2c2dc20d.
# Processed participant 2c3b09db.
# Processed participant 2c406043.
# Processed participant 2c483245.
# Processed participant 2c54d6c5.
# Processed participant 2ca2206f.
# Processed participant 2cb0db2c.
# Processed participant 2cd9b5a3.
# Processed participant 2cda86bd.
# Processed participant 2d0bbbd3.
# Processed participant 2da6bf6e.
# Processed participant 2e17c497.
# Processed participant 2e5f5207.
# Processed participant 2ee0a1e8.
# Processed participant 2f154763.
# Processed participant 2f16cad4.
# Processed participant 2f1af08a.
# Processed participant 2f8ec752.
# Processed participant 2fba6cf4.
# Processed participant 2fef897e.
# Processed participant 3065aa2f.
# Processed participant 30d2fd47.
# Processed participant 31648caa.
# Processed participant 31b74cd4.
# Processed participant 31d61741.
# Processed participant 31f01671.
# Processed participant 321202d4.
# Processed participant 3216b978.
# Processed participant 325afd3d.
# Processed participant 3268c574.
# Processed participant 327ef356.
# Processed participant 32b8490d.
# Processed participant 32dcc8ab.
# Processed participant 331733c7.
# Processed participant 338146bd.
# Processed participant 33d60f7d.
# Processed participant 33fe1b04.
# Processed participant 34362a9a.
# Processed participant 34ec5de4.
# Processed participant 350cf38b.
# Processed participant 350dbeba.
# Processed participant 35198c2d.
# Processed participant 351cd4ec.
# Processed participant 35d2aa41.
# Processed participant 35daea65.
# Processed participant 35fa2ebf.
# Processed participant 36530d36.
# Processed participant 36c060b9.
# Processed participant 36c1f189.
# Processed participant 372a7950.
# Processed participant 37995242.
# Processed participant 37ae1239.
# Processed participant 37bcfa7e.
# Processed participant 380029ef.
# Processed participant 3826be66.
# Processed participant 384c3f27.
# Processed participant 3875d4de.
# Processed participant 38cccd6d.
# Processed participant 38d53b92.
# Processed participant 3950aa00.
# Processed participant 397efe7a.
# Processed participant 3983d3cd.
# Processed participant 39fb1ad0.
# Processed participant 3a594acf.
# Processed participant 3ab539f0.
# Processed participant 3acb5be3.
# Processed participant 3b091b83.
# Processed participant 3b1b9538.
# Processed participant 3ba48ca7.
# Processed participant 3c0aba64.
# Processed participant 3c2cf08e.
# Processed participant 3c620257.
# Processed participant 3c8f474a.
# Processed participant 3ca35642.
# Processed participant 3d36fe8b.
# Processed participant 3d3b87db.
# Processed participant 3d3dd3ae.
# Processed participant 3d48430d.
# Processed participant 3d6143f3.
# Processed participant 3d736110.
# Processed participant 3d970ce4.
# Processed participant 3e398bf9.
# Processed participant 3e5d5b58.
# Processed participant 3e5ee48c.
# Processed participant 3f1cf5ba.
# Processed participant 3f1f23e7.
# Processed participant 3fcef947.
# Processed participant 40087bc5.
# Processed participant 408bed19.
# Processed participant 40aae75f.
# Processed participant 416b6ba2.
# Processed participant 4177e5e5.
# Processed participant 419d05c6.
# Processed participant 427037b2.
# Processed participant 4280076d.
# Processed participant 428970d4.
# Processed participant 428c37ea.
# Processed participant 429cc266.
# Processed participant 4307d287.
# Processed participant 432aff11.
# Processed participant 43629a34.
# Processed participant 436dd613.
# Processed participant 43720c15.
# Processed participant 43a7386d.
# Processed participant 43f44f6c.
# Processed participant 43f5d3c5.
# Processed participant 440acf4f.
# Processed participant 4442c376.
# Processed participant 4570c8b8.
# Processed participant 464a75fb.
# Processed participant 467c549f.
# Processed participant 47240aa3.
# Processed participant 47350ac6.
# Processed participant 481a1861.
# Processed participant 4859a9f9.
# Processed participant 48db8ecf.
# Processed participant 48df987b.
# Processed participant 48e69212.
# Processed participant 4926b18a.
# Processed participant 4940a214.
# Processed participant 4950e24c.
# Processed participant 49a1931d.
# Processed participant 49e4eade.
# Processed participant 4a1440d9.
# Processed participant 4a17b463.
# Processed participant 4a475a9f.
# Processed participant 4a4a0f78.
# Processed participant 4a62661a.
# Processed participant 4a6af685.
# Processed participant 4a9f92ca.
# Processed participant 4aa87859.
# Processed participant 4b0f961e.
# Processed participant 4b3c7594.
# Processed participant 4b71830a.
# Processed participant 4bc2bee9.
# Processed participant 4ca242ea.
# Processed participant 4cabd7aa.
# Processed participant 4cde1e34.
# Processed participant 4d19854c.
# Processed participant 4d5a8ce7.
# Processed participant 4d61a44e.
# Processed participant 4dc4ed56.
# Processed participant 4decbcd8.
# Processed participant 4dfb4e1d.
# Processed participant 4e6c7a75.
# Processed participant 4e85505f.
# Processed participant 4f059221.
# Processed participant 4f20b188.
# Processed participant 4fd7e043.
# Processed participant 50707f1e.
# Processed participant 50b2b84b.
# Processed participant 5124169c.
# Processed participant 5132511c.
# Processed participant 51364c23.
# Processed participant 51f38b37.
# Processed participant 5264bb0e.
# Processed participant 526f719b.
# Processed participant 52ce9b8b.
# Processed participant 52e9e467.
# Processed participant 537dc410.
# Processed participant 53814642.
# Processed participant 53905a2c.
# Processed participant 54391716.
# Processed participant 54945f30.
# Processed participant 54fef303.
# Processed participant 554e46e9.
# Processed participant 55f9338e.
# Processed participant 563ebc00.
# Processed participant 56cb7161.
# Processed participant 56d9dead.
# Processed participant 56ef356c.
# Processed participant 5779f2e9.
# Processed participant 579e50bd.
# Processed participant 57c4f2b4.
# Processed participant 57de6095.
# Processed participant 57f6fa6c.
# Processed participant 58391429.
# Processed participant 58ada72e.
# Processed participant 58dfccdb.
# Processed participant 5985f299.
# Processed participant 5a313293.
# Processed participant 5af79adb.
# Processed participant 5b2c9b83.
# Processed participant 5b66b6f2.
# Processed participant 5b9ff85e.
# Processed participant 5c186496.
# Processed participant 5c22f241.
# Processed participant 5c2c136d.
# Processed participant 5cd83147.
# Processed participant 5d3b6ea5.
# Processed participant 5d762840.
# Processed participant 5d885b20.
# Processed participant 5ddbac80.
# Processed participant 5e359a08.
# Processed participant 5e55e9fd.
# Processed participant 5e57bd12.
# Processed participant 5ea2c305.
# Processed participant 5ed5f205.
# Processed participant 5ee595e8.
# Processed participant 5ef3d64e.
# Processed participant 5f099188.
# Processed participant 5f1b07e1.
# Processed participant 5f37ceb1.
# Processed participant 5f574f3d.
# Processed participant 5f7537cf.
# Processed participant 5f78f7b9.
# Processed participant 5f9dddb4.
# Processed participant 60c1ff37.
# Processed participant 613fc399.
# Processed participant 6187d0dc.
# Processed participant 6197a2ce.
# Processed participant 621066ff.
# Processed participant 6247cc15.
# Processed participant 6282e693.
# Processed participant 62b873a2.
# Processed participant 62cd5c74.
# Processed participant 63d4ab9a.
# Processed participant 63fc9770.
# Processed participant 641697e6.
# Processed participant 649ff6d9.
# Processed participant 64b4005d.
# Processed participant 64ed48c4.
# Processed participant 658e66ec.
# Processed participant 6595d479.
# Processed participant 659fec57.
# Processed participant 65fe69c0.
# Processed participant 6699c999.
# Processed participant 66f619e3.
# Processed participant 677038b5.
# Processed participant 6774ba64.
# Processed participant 678598dd.
# Processed participant 6795027a.
# Processed participant 6826f0be.
# Processed participant 685cc0f1.
# Processed participant 687c85e7.
# Processed participant 68be3d5c.
# Processed participant 68fa4631.
# Processed participant 697c41d7.
# Processed participant 69b65679.
# Processed participant 6a16089d.
# Processed participant 6a2fd807.
# Processed participant 6a4df6ff.
# Processed participant 6a864b11.
# Processed participant 6abd21d4.
# Processed participant 6ac5763a.
# Processed participant 6ac5eaaf.
# Processed participant 6b6467f4.
# Processed participant 6b773506.
# Processed participant 6c0fe935.
# Processed participant 6c2edc91.
# Processed participant 6c6cd633.
# Processed participant 6c737069.
# Processed participant 6d5944a9.
# Processed participant 6d707ac3.
# Processed participant 6dfe4a75.
# Processed participant 6e128c6b.
# Processed participant 6e1d28b6.
# Processed participant 6e85a624.
# Processed participant 6e9beaee.
# Processed participant 6ebfdc95.
# Processed participant 6f49c8d0.
# Processed participant 6f5677b7.
# Processed participant 6fb28c2a.
# Processed participant 6fcdcb2a.
# Processed participant 7015528d.
# Processed participant 709457f3.
# Processed participant 70de1c63.
# Processed participant 71850348.
# Processed participant 71852781.
# Processed participant 7187caec.
# Processed participant 71c1b1d2.
# Processed participant 71ee31f8.
# Processed participant 721ea536.
# Processed participant 7265f1e5.
# Processed participant 72a0c969.
# Processed participant 72c9c38d.
# Processed participant 732b2327.
# Processed participant 7347b54e.
# Processed participant 73ec551e.
# Processed participant 73ffa609.
# Processed participant 745e6065.
# Processed participant 7494989e.
# Processed participant 75ad73ee.
# Processed participant 75b0446f.
# Processed participant 75b53bd4.
# Processed participant 75c13e08.
# Processed participant 764d8b42.
# Processed participant 76781cd8.
# Processed participant 76fb4afb.
# Processed participant 7800a084.
# Processed participant 7860b64c.
# Processed participant 78704d22.
# Processed participant 79bd36b6.
# Processed participant 7a0136e0.
# Processed participant 7a6d26a2.
# Processed participant 7b0a4060.
# Processed participant 7b543871.
# Processed participant 7b8842c3.
# Processed participant 7bdbf66f.
# Processed participant 7c194077.
# Processed participant 7c21ad67.
# Processed participant 7c39c8e5.
# Processed participant 7ce36c38.
# Processed participant 7d8f1716.
# Processed participant 7dc65b92.
# Processed participant 7e46b693.
# Processed participant 7e87087b.
# Processed participant 7f26f78c.
# Processed participant 7f2715b4.
# Processed participant 7f44236f.
# Processed participant 7fa51811.
# Processed participant 7fa7ccc4.
# Processed participant 806d877f.
# Processed participant 8078b7de.
# Processed participant 807d8908.
# Processed participant 80b46ffb.
# Processed participant 812f6873.
# Processed participant 8148c785.
# Processed participant 81a4b826.
# Processed participant 81d3ab22.
# Processed participant 81feecad.
# Processed participant 82ec9747.
# Processed participant 83379672.
# Processed participant 836b4de3.
# Processed participant 83711ef5.
# Processed participant 8376acc5.
# Processed participant 83846d0c.
# Processed participant 83912085.
# Processed participant 83eda373.
# Processed participant 84875079.
# Processed participant 84b7d89d.
# Processed participant 855c6099.
# Processed participant 857baaa6.
# Processed participant 85d99199.
# Processed participant 85d9c915.
# Processed participant 860f4f9c.
# Processed participant 86335468.
# Processed participant 863e40c7.
# Processed participant 86a8e0d6.
# Processed participant 86bd716a.
# Processed participant 87050a09.
# Processed participant 87af775e.
# Processed participant 8823b020.
# Processed participant 8875387b.
# Processed participant 893293dd.
# Processed participant 89739b1a.
# Processed participant 897da2c8.
# Processed participant 898096eb.
# Processed participant 89a26502.
# Processed participant 8a44ea3a.
# Processed participant 8a4e5d1a.
# Processed participant 8a645723.
# Processed participant 8a6b6912.
# Processed participant 8a77c3e9.
# Processed participant 8a9e653f.
# Processed participant 8abbbc38.
# Processed participant 8ba98f12.
# Processed participant 8c0ca955.
# Processed participant 8c1f9196.
# Processed participant 8c6c52a2.
# Processed participant 8cab7bc4.
# Processed participant 8d8b8553.
# Processed participant 8ddb6b8d.
# Processed participant 8e59a69a.
# Processed participant 8e749c85.
# Processed participant 8e80deb7.
# Processed participant 8ec2cc63.
# Processed participant 8f015125.
# Processed participant 8f21c613.
# Processed participant 8f2d131f.
# Processed participant 8f753551.
# Processed participant 8f9c03c6.
# Processed participant 90161e10.
# Processed participant 9027c805.
# Processed participant 9052579b.
# Processed participant 9061cc9c.
# Processed participant 9105b812.
# Processed participant 9130a22e.
# Processed participant 913bea9f.
# Processed participant 91656d27.
# Processed participant 92293b06.
# Processed participant 92622443.
# Processed participant 9271574b.
# Processed participant 92bb8516.
# Processed participant 930c567c.
# Processed participant 93559639.
# Processed participant 93904b23.
# Processed participant 93c06d4c.
# Processed participant 93c72a97.
# Processed participant 93c93585.
# Processed participant 93fd93c4.
# Processed participant 93fda84a.
# Processed participant 9402b885.
# Processed participant 948a7025.
# Processed participant 948e1435.
# Processed participant 949f94e5.
# Processed participant 94a1053b.
# Processed participant 9540fa8e.
# Processed participant 954a4c2e.
# Processed participant 9570bfb7.
# Processed participant 95cc96cc.
# Processed participant 95d57ff9.
# Processed participant 966161e7.
# Processed participant 96de5f57.
# Processed participant 97bb0cc0.
# Processed participant 98413061.
# Processed participant 98ed2153.
# Processed participant 994ee014.
# Processed participant 99b15811.
# Processed participant 9a2082cf.
# Processed participant 9a5aed6c.
# Processed participant 9a7e4c38.
# Processed participant 9aa1a2ae.
# Processed participant 9ab4909f.
# Processed participant 9b328d6c.
# Processed participant 9b96b0e4.
# Processed participant 9bdd6964.
# Processed participant 9c1ea003.
# Processed participant 9cba0d0e.
# Processed participant 9ce139d3.
# Processed participant 9cee3c19.
# Processed participant 9cf04c41.
# Processed participant 9d0670dd.
# Processed participant 9d1b2d2c.
# Processed participant 9d65adbf.
# Processed participant 9d6b1410.
# Processed participant 9dc74359.
# Processed participant 9ddb06db.
# Processed participant 9ddfb9e6.
# Processed participant 9e027e04.
# Processed participant 9e052412.
# Processed participant 9e171735.
# Processed participant 9e4385f7.
# Processed participant 9e964060.
# Processed participant 9eb283e4.
# Processed participant 9ebb73c7.
# Processed participant 9f3ca269.
# Processed participant 9f70688f.
# Processed participant 9f9be55c.
# Processed participant 9fa5cdfd.
# Processed participant 9fa68512.
# Processed participant 9fb96ae3.
# Processed participant 9ff73d95.
# Processed participant a00c85e7.
# Processed participant a0182b17.
# Processed participant a0522c83.
# Processed participant a08ebf6e.
# Processed participant a148b46f.
# Processed participant a1942b0b.
# Processed participant a1ab89aa.
# Processed participant a221c60c.
# Processed participant a26c3e8f.
# Processed participant a28c7891.
# Processed participant a297d1b9.
# Processed participant a2994e55.
# Processed participant a302a015.
# Processed participant a3391798.
# Processed participant a3858c6a.
# Processed participant a3b146ca.
# Processed participant a3bd8858.
# Processed participant a402c6c8.
# Processed participant a40c8316.
# Processed participant a4481101.
# Processed participant a4530b41.
# Processed participant a49eda7f.
# Processed participant a4e0447e.
# Processed participant a4f13c0d.
# Processed participant a5078c62.
# Processed participant a5099438.
# Processed participant a5710c0a.
# Processed participant a5974a7d.
# Processed participant a5dbb00a.
# Processed participant a614af1b.
# Processed participant a65b2226.
# Processed participant a6969e1a.
# Processed participant a6fbb2e7.
# Processed participant a774c63b.
# Processed participant a7b9546a.
# Processed participant a808ad0a.
# Processed participant a814e825.
# Processed participant a8926a86.
# Processed participant a8b0428d.
# Processed participant a8c1aab5.
# Processed participant a8d9de72.
# Processed participant a922ef3f.
# Processed participant a95b4487.
# Processed participant a9b84b96.
# Processed participant a9c53cdb.
# Processed participant aa1700c7.
# Processed participant aae9800e.
# Processed participant aaefeff0.
# Processed participant ab16a20d.
# Processed participant ab2ad965.
# Processed participant ab36aa48.
# Processed participant ab54c39e.
# Processed participant ab987c75.
# Processed participant abac67cc.
# Processed participant abaf745c.
# Processed participant ac1ad4a7.
# Processed participant ac3ba541.
# Processed participant ac66c144.
# Processed participant ad0bbf35.
# Processed participant ad380962.
# Processed participant ad536dea.
# Processed participant ad9f821d.
# Processed participant adaf7461.
# Processed participant adba23f0.
# Processed participant adbd6839.
# Processed participant adc2d620.
# Processed participant ae712150.
# Processed participant aecc7e74.
# Processed participant af485add.
# Processed participant af4f064e.
# Processed participant b074f33b.
# Processed participant b08423c5.
# Processed participant b08f0ca4.
# Processed participant b120a337.
# Processed participant b1de4423.
# Processed participant b1f064ac.
# Processed participant b23b9220.
# Processed participant b25abc27.
# Processed participant b2987a65.
# Processed participant b2b56219.
# Processed participant b308c03e.
# Processed participant b37281d5.
# Processed participant b3b200af.
# Processed participant b3f5c066.
# Processed participant b41cee02.
# Processed participant b447e66d.
# Processed participant b452f767.
# Processed participant b4e69f09.
# Processed participant b69bf1f7.
# Processed participant b712b69b.
# Processed participant b7a61f8d.
# Processed participant b7c410a9.
# Processed participant b802aec3.
# Processed participant b823508b.
# Processed participant b94ec4a1.
# Processed participant b95aad8d.
# Processed participant b9b22bff.
# Processed participant b9c085ab.
# Processed participant b9cf3f7c.
# Processed participant b9e90f7f.
# Processed participant ba73bc7c.
# Processed participant bb0d7d92.
# Processed participant bb808a71.
# Processed participant bba6ff20.
# Processed participant bbd71a7c.
# Processed participant bbe5bedd.
# Processed participant bc4eaf77.
# Processed participant bc66f41d.
# Processed participant bc6bd8b2.
# Processed participant bd4ccd4c.
# Processed participant bd8397cb.
# Processed participant bdbff28b.
# Processed participant bdcc7d10.
# Processed participant be210bc7.
# Processed participant bea525dc.
# Processed participant bebff291.
# Processed participant bf31e0a7.
# Processed participant bfb421f9.
# Processed participant c00c663c.
# Processed participant c0442863.
# Processed participant c09d41cd.
# Processed participant c0a7d046.
# Processed participant c0f2a046.
# Processed participant c1373df0.
# Processed participant c274a243.
# Processed participant c294b507.
# Processed participant c2b40d6f.
# Processed participant c2e15338.
# Processed participant c3061b23.
# Processed participant c308b134.
# Processed participant c38585c5.
# Processed participant c38a5c9b.
# Processed participant c3a3f61e.
# Processed participant c3a86e3e.
# Processed participant c3adae87.
# Processed participant c3d46daf.
# Processed participant c3dde859.
# Processed participant c446e1c5.
# Processed participant c45068a1.
# Processed participant c4c2076b.
# Processed participant c5462e87.
# Processed participant c55187b4.
# Processed participant c5cfaeae.
# Processed participant c6313b18.
# Processed participant c6575d38.
# Processed participant c6cc7467.
# Processed participant c6d4b453.
# Processed participant c6da0d4b.
# Processed participant c6ead822.
# Processed participant c731458f.
# Processed participant c73dd2e4.
# Processed participant c73f149c.
# Processed participant c79039af.
# Processed participant c7d9e964.
# Processed participant c8270746.
# Processed participant c829500d.
# Processed participant c8cc2e1b.
# Processed participant c8fbbc8a.
# Processed participant c9600298.
# Processed participant c96b9609.
# Processed participant c9879365.
# Processed participant c9902f48.
# Processed participant c9dabad5.
# Processed participant c9e419e7.
# Processed participant ca3204b0.
# Processed participant ca33a5e7.
# Processed participant cadd4ae5.
# Processed participant cb2752bc.
# Processed participant cb3b7c3c.
# Processed participant cb73fed9.
# Processed participant cba39753.
# Processed participant cbcf8cf2.
# Processed participant cd144127.
# Processed participant cd1fff5a.
# Processed participant cd39e576.
# Processed participant cd68643b.
# Processed participant cd703872.
# Processed participant cd89d5f1.
# Processed participant cd8f3c61.
# Processed participant cda90e9e.
# Processed participant ce379a6a.
# Processed participant ce6eeadf.
# Processed participant cefdb7fe.
# Processed participant cf1b9d44.
# Processed participant cfcf9dc9.
# Processed participant cfe4cf40.
# Processed participant d05f5d71.
# Processed participant d08806a2.
# Processed participant d0ac4f1c.
# Processed participant d19e1025.
# Processed participant d28f0d44.
# Processed participant d2d9b474.
# Processed participant d3da09e8.
# Processed participant d445fb74.
# Processed participant d4d2f272.
# Processed participant d4d9f7f9.
# Processed participant d506f4c7.
# Processed participant d57f6c9e.
# Processed participant d5a8d9b0.
# Processed participant d5b089a4.
# Processed participant d5fde276.
# Processed participant d6251195.
# Processed participant d661ddf7.
# Processed participant d6776176.
# Processed participant d6cca65e.
# Processed participant d74e4d7c.
# Processed participant d77ac332.
# Processed participant d791703f.
# Processed participant d8037389.
# Processed participant d859115e.
# Processed participant d87e2d01.
# Processed participant d9c82502.
# Processed participant da09ed4b.
# Processed participant da19c97e.
# Processed participant da5a8921.
# Processed participant dacc2f83.
# Processed participant daf3969c.
# Processed participant db23fbe4.
# Processed participant db38d1f9.
# Processed participant db3b1dd1.
# Processed participant db746de0.
# Processed participant db9eae59.
# Processed participant dc33dcef.
# Processed participant dcfcd574.
# Processed participant dd689eb0.
# Processed participant dd747bba.
# Processed participant de3750cc.
# Processed participant de3ecca9.
# Processed participant de742c5c.
# Processed participant de91310c.
# Processed participant df4ab9b1.
# Processed participant df556fd2.
# Processed participant df98fbb4.
# Processed participant e0283d3d.
# Processed participant e0655da2.
# Processed participant e072b994.
# Processed participant e0869709.
# Processed participant e0ad6550.
# Processed participant e0db55b1.
# Processed participant e1958a83.
# Processed participant e1a4575f.
# Processed participant e1ccc3d1.
# Processed participant e1e02e28.
# Processed participant e1ea8dd7.
# Processed participant e21255e2.
# Processed participant e23a8a0a.
# Processed participant e243119c.
# Processed participant e28c0bfa.
# Processed participant e315fdd7.
# Processed participant e328a032.
# Processed participant e37d000b.
# Processed participant e3bce7e1.
# Processed participant e3f71f7a.
# Processed participant e40319d7.
# Processed participant e4614ec6.
# Processed participant e46417a7.
# Processed participant e4762a2b.
# Processed participant e4ab3b12.
# Processed participant e4b47411.
# Processed participant e4d396d7.
# Processed participant e4e58096.
# Processed participant e51193d1.
# Processed participant e5349ce2.
# Processed participant e63000c5.
# Processed participant e683d2c9.
# Processed participant e7401605.
# Processed participant e754411f.
# Processed participant e76ad778.
# Processed participant e7d08824.
# Processed participant e88aa867.
# Processed participant e892aec6.
# Processed participant e8b64419.
# Processed participant e8e82627.
# Processed participant e9ca5586.
# Processed participant e9d94c4e.
# Processed participant ea4619ec.
# Processed participant ea544af3.
# Processed participant ea7277b4.
# Processed participant ea7adcd6.
# Processed participant eaab7a96.
# Processed participant eb93a46a.
# Processed participant ebd6f819.
# Processed participant ebf2b0c9.
# Processed participant ebf30e46.
# Processed participant ec13a1b9.
# Processed participant ec6b57b4.
# Processed participant ec8f8f95.
# Processed participant ec9195be.
# Processed participant ecd25dd1.
# Processed participant ed0b3906.
# Processed participant ed711416.
# Processed participant edb9d0f3.
# Processed participant ee21612e.
# Processed participant ee2bf575.
# Processed participant ee67eb55.
# Processed participant eeedcd5e.
# Processed participant eef79620.
# Processed participant ef07f833.
# Processed participant ef58dd3c.
# Processed participant ef9617e7.
# Processed participant efa35d35.
# Processed participant f015a18c.
# Processed participant f028534c.
# Processed participant f0957ca1.
# Processed participant f09e7b33.
# Processed participant f0d76b32.
# Processed participant f1049268.
# Processed participant f11e17c0.
# Processed participant f1baae47.
# Processed participant f1bd0f59.
# Processed participant f285b43c.
# Processed participant f2d4efd8.
# Processed participant f3020788.
# Processed participant f32a9580.
# Processed participant f35b607c.
# Processed participant f4114031.
# Processed participant f420b05a.
# Processed participant f44f1227.
# Processed participant f47a67cc.
# Processed participant f47abc42.
# Processed participant f4d2f5af.
# Processed participant f57de847.
# Processed participant f584742f.
# Processed participant f5ad7abc.
# Processed participant f5b2acf0.
# Processed participant f62b317d.
# Processed participant f64ae747.
# Processed participant f67908e7.
# Processed participant f6b719ee.
# Processed participant f6c0e2b7.
# Processed participant f6c20447.
# Processed participant f6cc80a9.
# Processed participant f6d6f400.
# Processed participant f6d879aa.
# Processed participant f74eda33.
# Processed participant f75c957f.
# Processed participant f7b1374e.
# Processed participant f7fc97cf.
# Processed participant f81598bf.
# Processed participant f8674e15.
# Processed participant f869d220.
# Processed participant f8bf4a1c.
# Processed participant f8ff0bc8.
# Processed participant f93010a8.
# Processed participant f9334e08.
# Processed participant f9384fa2.
# Processed participant fa34f945.
# Processed participant fa3e1e21.
# Processed participant fa633e39.
# Processed participant fa9a0add.
# Processed participant fab75c2c.
# Processed participant fad07fce.
# Processed participant fb04f7dd.
# Processed participant fb3c2c87.
# Processed participant fb9c5a33.
# Processed participant fc2c2c08.
# Processed participant fc41be2f.
# Processed participant fc49ba65.
# Processed participant fc8e4de4.
# Processed participant fd028ecc.
# Processed participant fd0d9bca.
# Processed participant fd56e059.
# Processed participant fdb6b48b.
# Processed participant fdc11b96.
# Processed participant fdea7d9e.
# Processed participant fdf4691f.
# Processed participant fe3cbf02.
# Processed participant fe9c71d8.
# Processed participant fecc07d6.
# Processed participant ff18b749.
# Processed participant ffcd4dbd.
# Processed participant ffed1dd5.
# Consolidated features saved successfully to C:/Users/Lenovo/OneDrive/Desktop/SEM 2/ml/project/consolidated_features.parquet
# (996, 18)

# %%
import pandas as pd

# Path to the input Parquet file
input_parquet_file = "C:/Users/Lenovo/OneDrive/Desktop/SEM 2/ml/project/consolidated_features.parquet"

# Path for the output CSV file
output_csv_file = "C:/Users/Lenovo/OneDrive/Desktop/SEM 2/ml/project/consolidated_features.csv"

# Read the Parquet file into a DataFrame
try:
    df = pd.read_parquet(input_parquet_file)
    print(f"Loaded Parquet file with shape {df.shape}.")
    
    # Save the DataFrame as a CSV file
    df.to_csv(output_csv_file, index=False)
    print(f"CSV file saved successfully to {output_csv_file}.")
except Exception as e:
    print(f"Error processing file: {e}")
# Out:
# Loaded Parquet file with shape (996, 18).
# CSV file saved successfully to C:/Users/Lenovo/OneDrive/Desktop/SEM 2/ml/project/consolidated_features.csv.

# %%
import os
import pandas as pd
import numpy as np

# Function to extract features from Actigraphy data
def extract_features(data):
    mean_x = data['X'].mean()
    mean_y = data['Y'].mean()
    mean_z = data['Z'].mean()
    std_x = data['X'].std()
    std_y = data['Y'].std()
    std_z = data['Z'].std()
    mean_enmo = data['enmo'].mean()
    std_enmo = data['enmo'].std()
    max_enmo = data['enmo'].max()
    min_enmo = data['enmo'].min()
    magnitude = np.sqrt(data['X']**2 + data['Y']**2 + data['Z']**2)
    mean_magnitude = magnitude.mean()
    std_magnitude = magnitude.std()
    inactivity_percentage = (data['enmo'] == 0).mean() * 100
    non_wear_percentage = (data['non-wear_flag'] == 1).mean() * 100

    # Created a dictionary with the extracted features
    features = {
        'mean_x': mean_x,
        'mean_y': mean_y,
        'mean_z': mean_z,
        'std_x': std_x,
        'std_y': std_y,
        'std_z': std_z,
        'mean_enmo': mean_enmo,
        'std_enmo': std_enmo,
        'max_enmo': max_enmo,
        'min_enmo': min_enmo,
        'mean_magnitude': mean_magnitude,
        'std_magnitude': std_magnitude,
        'inactivity_percentage': inactivity_percentage,
        'non_wear_percentage': non_wear_percentage
    }
    return features

# Directory containing the participant files
input_directory = "C:/Users/Lenovo/OneDrive/Desktop/SEM 2/ml/project/cleaned_series_train.parquet"
output_directory = "C:/Users/Lenovo/OneDrive/Desktop/SEM 2/ml/project/extracted_features"
os.makedirs(output_directory, exist_ok=True)

# Listed all parquet files
parquet_files = [os.path.join(input_directory, file) for file in os.listdir(input_directory) if file.endswith('.parquet')]

# Initialized a list to store features
all_features = []

# Processed each file
for file in parquet_files:
    try:
        # Extracted participant ID from file name
        participant_id = file.split('id=')[-1].split('.')[0]
        
        # Loaded the data
        data = pd.read_parquet(file)
        
        # Extracted features
        features = extract_features(data)
        features['participant_id'] = participant_id  # Add participant ID
        
        # Appended features to the list
        all_features.append(features)
    except Exception as e:
        print(f"Error processing file {file}: {e}")

# Converted the list of features to a DataFrame
final_features = pd.DataFrame(all_features)

# Saved the DataFrame to a parquet file
output_parquet_file = os.path.join(output_directory, "extracted_features_all_participants.parquet")
final_features.to_parquet(output_parquet_file, index=False)

# Saved the DataFrame to a CSV file
output_csv_file = os.path.join(output_directory, "extracted_features_all_participants.csv")
final_features.to_csv(output_csv_file, index=False)

# Output success messages
print(f"Features successfully saved as a parquet file at: {output_parquet_file}")
print(f"Features successfully saved as a CSV file at: {output_csv_file}")
# Out:
# Features successfully saved as a parquet file at: C:/Users/Lenovo/OneDrive/Desktop/SEM 2/ml/project/extracted_features\extracted_features_all_participants.parquet
# Features successfully saved as a CSV file at: C:/Users/Lenovo/OneDrive/Desktop/SEM 2/ml/project/extracted_features\extracted_features_all_participants.csv
